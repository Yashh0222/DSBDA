# %%
import pandas as pd

# %%
df = pd.read_csv(
    "amazon.csv",
    engine="python",
    on_bad_lines="skip"
)

# %%
df
# Out:
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1    B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3    B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4    B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ..          ...                                                ...
# 334  B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 335  B0B3RRWSF6  Fire-Boltt Phoenix Smart Watch with Bluetooth ...
# 336  B0B5B6PQCT  boAt Wave Call Smart Watch, Smart Talk with Ad...
# 337  B08HV83HL3  MI Power Bank 3i 20000mAh Lithium Polymer 18W ...
# 338  B0BBN4DZBD  Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...
#
#                                               category discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           339 non-null    object
#  1   product_name         339 non-null    object
#  2   category             339 non-null    object
#  3   discounted_price     339 non-null    object
#  4   actual_price         339 non-null    object
#  5   discount_percentage  339 non-null    object
#  6   rating               339 non-null    float64
#  7   rating_count         337 non-null    object
#  8   about_product        339 non-null    object
#  9   user_id              339 non-null    object
#  10  user_name            339 non-null    object
#  11  review_id            339 non-null    object
#  12  review_title         339 non-null    object
#  13  review_content       339 non-null    object
#  14  img_link             339 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
x=df[['product_id', 'product_name', 'category', 'discounted_price',
       'actual_price', 'discount_percentage', 'rating', 'rating_count',
       'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
       'review_content', 'img_link', 'product_link']]

# %%
x
# Out:
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1    B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3    B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4    B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ..          ...                                                ...
# 334  B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 335  B0B3RRWSF6  Fire-Boltt Phoenix Smart Watch with Bluetooth ...
# 336  B0B5B6PQCT  boAt Wave Call Smart Watch, Smart Talk with Ad...
# 337  B08HV83HL3  MI Power Bank 3i 20000mAh Lithium Polymer 18W ...
# 338  B0BBN4DZBD  Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...
#
#                                               category discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...
